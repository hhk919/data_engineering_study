# %%
from google.colab import drive
from os.path import join
ROOT = "/content/drive"
print(ROOT)
drive.mount(ROOT)
# Out:
# /content/drive
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
access_token = "0eb7d9dde025828a67acebead5f9eb3d9ec457d3"
# Out:
# '/content/drive/My Drive/Colab Notebooks/data_engineering_study'

# %%
from os.path import join

MY_GOOGLE_DRIVE_PATH = "My Drive/Colab Notebooks/data_engineering_study"
GIT_USERNAME = "hhk919"
GIT_ACCESS_TOKEN = "0eb7d9dde025828a67acebead5f9eb3d9ec457d3"
GIT_REPOSITORY = "data_engineering_study"

PROJECT_PATH = join(ROOT, MY_GOOGLE_DRIVE_PATH)

print(PROJECT_PATH)

GIT_PATH = "https://"+GIT_ACCESS_TOKEN+"@github.com/"+GIT_USERNAME+"/"+GIT_REPOSITORY+".git"
print(GIT_PATH)
# Out:
# /content/drive/My Drive/Colab Notebooks/data_engineering_study
# https://0eb7d9dde025828a67acebead5f9eb3d9ec457d3@github.com/hhk919/data_engineering_study.git

# %%
# !git branch
